# %%
import pandas as pd
import math

   
df = pd.read_csv('E:\Task scheduling project\priority.csv')
df.head(10)
# Out:
#    Task ID  Estimated Execution Time          Deadline Criticality Level
# 0        1                        10  20-01-2024 12:00              High  \
# 1        2                        20  20-01-2024 12:30            Medium
# 2        3                        15  20-01-2024 13:00               Low
# 3        4                         8  20-01-2024 13:30              High
# 4        5                        25  20-01-2024 14:00            Medium
# 5        6                        12  20-01-2024 14:30               Low
# 6        7                        18  20-01-2024 15:00              High
# 7        8                        22  20-01-2024 15:30            Medium
# 8        9                        10  20-01-2024 16:00               Low
# 9       10                        30  20-01-2024 16:30              High
#
#         Device Type  Actual Execution Time Priority
# 0  Local Fog Device                    8.0     High
# 1          Fog Node                   18.0   Medium
# ...
